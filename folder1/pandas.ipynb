# %%
# !pip3 install pandas
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 28.6 MB/s  0:00:00m0:00:010:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...

# %%
import pandas as pd

# %%
pd.Series([96.9,78.5,50.4,34.9,12.8])
# Out:
# 0    96.9
# 1    78.5
# 2    50.4
# 3    34.9
# 4    12.8
# dtype: float64

# %%
pd.Series([96.9,78.5,50.4,34.9,12.8],index = ["Alice","Bob","Charlie","Diana","Smith"])
# Out:
# Alice      96.9
# Bob        78.5
# Charlie    50.4
# Diana      34.9
# Smith      12.8
# dtype: float64

# %%
pd.Series([96.9,78.5,50.4,34.9,12.8],index = ["Alice","Bob","Charlie","Diana","Smith"])

data = {"Alice":96.9,"Bob":78.5,"Charlie":50.4,"Diana":34.9,"Smith":12.8}

# %%
data
# Out:
# {'Alice': 96.9, 'Bob': 78.5, 'Charlie': 50.4, 'Diana': 34.9, 'Smith': 12.8}

# %%
pd.Series(data)
# Out:
# Alice      96.9
# Bob        78.5
# Charlie    50.4
# Diana      34.9
# Smith      12.8
# dtype: float64

# %%
 scores = pd.Series(data)

# %%
scores
# Out:
# Alice      96.9
# Bob        78.5
# Charlie    50.4
# Diana      34.9
# Smith      12.8
# dtype: float64

# %%
scores.values
# Out:
# array([96.9, 78.5, 50.4, 34.9, 12.8])

# %%
  sum = scores.values.sum

# %%
sum
# Out:
# <function ndarray.sum>

# %%
scores = pd.Series([96.9,78.5,50.4,34.9,12.8])
scores.sum()
# Out:
# np.float64(273.5)

# %%
scores.mean()
# Out:
# np.float64(54.7)

# %%
scores.median()
# Out:
# np.float64(50.4)

# %%
scores.min()
# Out:
# np.float64(12.8)

# %%
scores.max()
# Out:
# np.float64(96.9)

# %%
scores.values *2
# Out:
# array([193.8, 157. , 100.8,  69.8,  25.6])

# %%
scores.values > 50
# Out:
# array([ True,  True,  True, False, False])

# %%
pd.Series(scores,name = "Exam scores")
# Out:
# 0    96.9
# 1    78.5
# 2    50.4
# 3    34.9
# 4    12.8
# Name: Exam scores, dtype: float64
